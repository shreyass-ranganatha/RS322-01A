# %%
import matplotlib.pyplot as pt

import numpy as np
import cv2

from pathlib import Path
import glob
import os

# %%
res_path = Path("../outputs/dataset")

for f in glob.glob(str(res_path / "*.npy")):
    iid = os.path.basename(f)
    m = np.load(f)

    print(f"{iid:>40}\t{np.unique(m)}")

    # if "mango" in iid:
    #     m[m != 0] = 2
    #     np.save(f, m)
# Out:
#              high_density_coconut_56.npy	[0 1]
#              high_density_coconut_42.npy	[0 1]
#              high_density_coconut_81.npy	[0 1]
#               low_density_coconut_90.npy	[0 1]
#              medium_density_mango_46.npy	[0 2]
#                high_density_mango_61.npy	[0 2]
#                high_density_mango_75.npy	[0 2]
#                 low_density_mango_19.npy	[0 2]
#               low_density_coconut_84.npy	[0 1]
#              medium_density_mango_52.npy	[0 2]
#                 low_density_mango_31.npy	[0 2]
#                 low_density_mango_25.npy	[0 2]
#               low_density_coconut_53.npy	[0 1]
#              medium_density_mango_85.npy	[0 2]
#            medium_density_coconut_28.npy	[0 1]
#               low_density_coconut_47.npy	[0 1]
#            medium_density_coconut_14.npy	[0 1]
#               medium_density_mango_8.npy	[0 2]
#               medium_density_mango_9.npy	[0 2]
#            medium_density_coconut_15.npy	[0 1]
# ...
