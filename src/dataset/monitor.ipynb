# %%
import json

# %%
train_ds = json.load(open("coco/train.json"))
test_ds = json.load(open("coco/test.json"))
validation_ds = json.load(open("coco/validation.json"))

train_ds.keys()
# Out:
# dict_keys(['images', 'annotations', 'categories'])

# %%
len(train_ds["images"]), len(test_ds["images"]), len(validation_ds["images"])
# Out:
# (394, 85, 71)

# %%
394 + 85 + 71
# Out:
# 550
